# %%
import numpy as np
import pandas as pd

# %%
print("Conda Environment Successfully Configured!")
# Out:
# Conda Environment Successfully Configured!

# %%
arr = np.array([10,20,30,40,50])
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
df = pd.DataFrame({
    "Student":["Alice","Bob","Charlie"],
    "Marks":[85,90,88]
})

df
# Out:
#    Student  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     88
